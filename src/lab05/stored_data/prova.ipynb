# %%
import numpy as np


A = random_matrix_floats = np.random.uniform(-1, 1, size=(10, 2))

B = random_matrix_floats = np.random.uniform(-1, 1, size=(10, 2))


err = np.linalg.norm(A-B, axis=-1)
err_squared = np.square(err)
mean_err = np.sum(err_squared)/10
rmse = np.sqrt(mean_err)

MAE = np.max(np.abs(sqrt))
TCE = np.sum(sqrt)

Ax = A[:,0]
Ay = A[:,-1]
cock = 0.0
for i in range(9):
    x = Ax[i+1]-Ax[i]
    y = Ay[i+1]-Ay[i]
    d = np.sqrt(x**2+y**2)
    cock += d
print(str('your cock is long: ') + str(float(cock)) + str(' millimeters'))
e_p_odom = TCE/cock
print(e_p_odom)
print('A',A,'B', B, 'diff',diff, 'sum', sum , 'sqrt', sqrt, 'sum_squared', sum_squared, 'sum_div', sum_div, 'div', div, 'rmse', rmse, 'MAE', MAE, 'TCE', TCE, 'try_norm', try_norm, try_norm2 )
# Out:
# your cock is long: 7.490795777491996 millimeters
# 1.3031706599388033
# A [[ 0.28923837 -0.31945571]
#  [-0.44503474  0.50890187]
#  [-0.59849832  0.10890847]
#  [ 0.39277733 -0.51904157]
#  [ 0.71687287 -0.65462877]
#  [ 0.71993625  0.88925946]
#  [ 0.11265196  0.81943209]
#  [-0.0439712   0.03381652]
#  [-0.64531121 -0.21514148]
#  [ 0.14254393  0.02481319]] B [[ 0.48624676 -0.62904607]
#  [ 0.48465399 -0.98340979]
#  [ 0.81518235 -0.33849821]
#  [ 0.66469894 -0.82152339]
#  [ 0.80070213 -0.33273466]
#  [ 0.211676    0.51786409]
#  [-0.6051495   0.32520461]
#  [ 0.24429728 -0.12188451]
#  [-0.48310936 -0.17834856]
#  [-0.05148803 -0.43130959]] diff [[3.37121286e-03 5.96580606e-01]
#  [1.79268071e+00 6.07495194e-01]
#  [1.43639995e-03 6.88757349e-02]
#  [1.64235306e+00 8.52658221e-01]
#  [1.00348425e-02 6.38653287e-01]
#  [1.00575862e-03 5.23030422e-02]
#  [2.44617823e-01 2.99969415e-01]
#  [3.57597563e-01 9.32360453e-01]
#  [2.83720495e+00 1.37549277e+00]
# ...
